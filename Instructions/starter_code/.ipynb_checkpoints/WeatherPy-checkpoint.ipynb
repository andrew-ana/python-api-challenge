# %% [markdown]
# # WeatherPy
# ----
# Andrew Anastasiades | @andrew-ana

# %% [markdown]
# ## Initialize

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 605

# %% [markdown]
# ## Perform API Calls

# %%
print("Beginning API Calls")
print("------------------------")

url = "http://api.openweathermap.org/data/2.5/weather"

#The API says we can do 60 calls a minute. I didn't have that issue, but I don't want to get pinged for that
#So you are going to have to wait. But I will try to optimize wait time <3
begin = time.time()

#Create empty DataFrame
weather_df = pd.DataFrame(columns=["City", "Response Code", "Exec Time(s)","Longitude","Latitude",
                                  "Weather", "Temperature (F)","Cloudiness (%)","Wind Speed (mph)", "Humidity (%)" ])
i = 1

#ITERATE THROUGH CITIES
for city in cities:
    call_start = time.time()#Time each api call
    response = requests.get(url, params={'q': city, 'appid': weather_api_key, 'units':'imperial'})
    if response.status_code == 200:
        print(f"{i}. {city}: Results Found! {time.time()-call_start:.3f}s")
    else:
        print(f"{i}. {city}: Results not Found :( {time.time()-call_start:.3f}s")
    
    #EXTRACT VALUES FROM RESPONSE
    #LONGITUDE
    try:
        lon = response.json()["coord"]["lon"]
    except:
        lon = np.nan
    #LATITUDE
    try:
        lat = response.json()["coord"]["lat"]
    except:
        lat = np.nan
    #WEATHER
    try:
        weather = response.json()['weather'][0]['main']
    except:
        weather = ""
    #TEMPERATURE
    try:
        temp = response.json()['main']['temp_max']
    except:
        temp = np.nan
    #CLOUDINESS
    try:
        clouds = response.json()['clouds']['all']
    except:
        clouds = np.nan
    #WIND SPEED
    try:
        wind_speed = response.json()['wind']['speed']
    except:
        wind_speed = np.nan
    try:
        humidity = response.json()['main']['humidity']
    except:
        wind_speed = np.nan
    
    #APPEND ROW TO DF
    weather_df = weather_df.append({
        "City": city, 
        "Response Code": response.status_code, 
        "Exec Time(s)": time.time()-call_start,
        "Latitude" : lat,
        "Longitude" : lon,
        "Weather" : weather,
        "Cloudiness (%)" : clouds,
        "Temperature (F)" : temp,
        "Wind Speed (mph)" : wind_speed,
        "Humidity (%)" : humidity,
        
    }, ignore_index=True)
    
    #increment counter
    i += 1 
    #Check if we need to sleep!
    if i % 60 == 0:
        current = time.time() - begin
        wait_time = 60*(i//60)-current
        print(f"Executed 60 calls, waiting for {wait_time:.2f} seconds")
        time.sleep(wait_time)
        
print(f"Total Execution: {time.time()-begin}s")
# Save the DataFrame
weather_df.to_csv("Output/cities.csv")
# Out:
# Beginning API Calls
# ------------------------
# 1. tuktoyaktuk: Results Found! 0.140s
# 2. aklavik: Results Found! 0.074s
# 3. caravelas: Results Found! 0.071s
# 4. kapaa: Results Found! 0.173s
# 5. severo-kurilsk: Results Found! 0.098s
# 6. aswan: Results Found! 0.073s
# 7. petropavlovsk-kamchatskiy: Results Found! 0.103s
# 8. bengkulu: Results Found! 0.289s
# 9. illoqqortoormiut: Results not Found :( 0.075s
# 10. yueyang: Results Found! 0.084s
# 11. fevralsk: Results not Found :( 0.104s
# 12. tura: Results Found! 0.166s
# 13. torbay: Results Found! 0.077s
# 14. mazatlan: Results Found! 0.118s
# 15. hobart: Results Found! 0.073s
# 16. thompson: Results Found! 0.266s
# 17. ushuaia: Results Found! 0.090s
# 18. busselton: Results Found! 0.070s
# 19. bluff: Results Found! 0.072s
# 20. chuy: Results Found! 0.169s
# 21. mataura: Results Found! 0.328s
# 22. cape town: Results Found! 0.303s
# 23. hilo: Results Found! 0.071s
# 24. new norfolk: Results Found! 0.100s
# 25. touros: Results Found! 0.148s
# 26. vaini: Results Found! 0.075s
# 27. jamestown: Results Found! 0.074s
# 28. naze: Results Found! 0.072s
# 29. sao filipe: Results Found! 0.154s
# 30. mocuba: Results Found! 0.367s
# 31. khatanga: Results Found! 0.073s
# 32. gazanjyk: Results Found! 0.162s
# 33. hermanus: Results Found! 0.097s
# 34. ammon: Results Found! 0.101s
# 35. rikitea: Results Found! 0.070s
# 36. messina: Results Found! 0.071s
# 37. renqiu: Results Found! 0.301s
# 38. hithadhoo: Results Found! 0.070s
# 39. port alfred: Results Found! 0.099s
# 40. san quintin: Results Found! 0.153s
# 41. kharp: Results Found! 0.078s
# 42. talnakh: Results Found! 0.089s
# 43. coro: Results Found! 0.100s
# 44. hamilton: Results Found! 0.079s
# 45. trinidad: Results Found! 0.326s
# 46. taolanaro: Results not Found :( 0.073s
# 47. yellowknife: Results Found! 0.070s
# 48. bhiwani: Results Found! 0.152s
# 49. esperance: Results Found! 0.092s
# 50. dwarka: Results Found! 0.078s
# 51. santa adelia: Results Found! 0.070s
# 52. guanhaes: Results Found! 0.074s
# 53. avarua: Results Found! 0.297s
# 54. klaksvik: Results Found! 0.117s
# 55. marawi: Results Found! 0.093s
# 56. albany: Results Found! 0.142s
# 57. lekoni: Results Found! 0.072s
# 58. lagoa: Results Found! 0.073s
# 59. puerto ayora: Results Found! 0.073s
# Executed 60 calls, waiting for 51.95 seconds
# 60. upata: Results Found! 0.102s
# 61. qasigiannguit: Results Found! 0.164s
# 62. grindavik: Results Found! 0.073s
# 63. georgetown: Results Found! 0.103s
# 64. calabozo: Results Found! 0.374s
# 65. sakakah: Results Found! 0.370s
# 66. faanui: Results Found! 0.085s
# 67. pevek: Results Found! 0.072s
# 68. cherskiy: Results Found! 0.080s
# 69. cidreira: Results Found! 0.070s
# 70. port-cartier: Results Found! 0.300s
# 71. saint-philippe: Results Found! 0.137s
# 72. kodiak: Results Found! 0.130s
# 73. tasiilaq: Results Found! 0.342s
# 74. antofagasta: Results Found! 0.904s
# 75. kavieng: Results Found! 0.520s
# 76. kruisfontein: Results Found! 0.185s
# 77. pisco: Results Found! 0.307s
# 78. yulara: Results Found! 0.240s
# 79. datong: Results Found! 0.477s
# 80. port elizabeth: Results Found! 0.164s
# 81. mys shmidta: Results not Found :( 0.333s
# 82. porto empedocle: Results Found! 0.293s
# 83. balabac: Results Found! 0.186s
# 84. saint george: Results Found! 0.070s
# 85. attawapiskat: Results not Found :( 0.411s
# 86. ponta do sol: Results Found! 0.073s
# 87. nome: Results Found! 0.447s
# 88. atuona: Results Found! 0.187s
# 89. belushya guba: Results not Found :( 0.300s
# 90. kamenskoye: Results not Found :( 0.070s
# 91. ribeira grande: Results Found! 0.441s
# 92. saskylakh: Results Found! 0.195s
# 93. khlung: Results Found! 0.336s
# 94. flinders: Results Found! 0.072s
# 95. butaritari: Results Found! 0.380s
# 96. east london: Results Found! 0.387s
# 97. minsk: Results Found! 0.095s
# 98. alice springs: Results Found! 0.118s
# 99. barrow: Results Found! 0.303s
# 100. barentsburg: Results not Found :( 0.121s
# 101. the valley: Results Found! 0.071s
# 102. abu jubayhah: Results not Found :( 0.181s
# 103. staroaleyskoye: Results Found! 0.075s
# 104. erenhot: Results Found! 0.076s
# 105. simao: Results Found! 0.069s
# 106. sentyabrskiy: Results not Found :( 0.323s
# 107. fairbanks: Results Found! 0.084s
# 108. gigmoto: Results Found! 0.086s
# 109. luganville: Results Found! 0.147s
# 110. bintulu: Results Found! 0.070s
# 111. sechura: Results Found! 0.071s
# 112. namibe: Results Found! 0.071s
# 113. porvoo: Results Found! 0.079s
# 114. nizhneyansk: Results not Found :( 0.073s
# 115. sembe: Results Found! 0.317s
# 116. koulikoro: Results Found! 0.070s
# 117. arraial do cabo: Results Found! 0.071s
# 118. clyde river: Results Found! 0.163s
# 119. soe: Results Found! 0.102s
# Executed 60 calls, waiting for 47.05 seconds
# 120. arman: Results Found! 0.072s
# 121. salacgriva: Results Found! 0.068s
# 122. provideniya: Results Found! 0.081s
# 123. buchanan: Results Found! 0.104s
# 124. talaya: Results Found! 0.529s
# 125. intipuca: Results Found! 0.348s
# 126. vila do maio: Results Found! 0.408s
# 127. bredasdorp: Results Found! 0.072s
# 128. beringovskiy: Results Found! 0.075s
# 129. samusu: Results not Found :( 0.096s
# 130. saint-augustin: Results Found! 0.343s
# 131. upernavik: Results Found! 0.410s
# 132. longyearbyen: Results Found! 0.276s
# 133. mahebourg: Results Found! 0.396s
# 134. oranjemund: Results Found! 0.070s
# 135. hualmay: Results Found! 0.264s
# 136. capiata: Results Found! 0.077s
# 137. samarai: Results Found! 0.082s
# 138. dakar: Results Found! 0.103s
# 139. husavik: Results Found! 0.157s
# 140. bethel: Results Found! 0.074s
# 141. bambous virieux: Results Found! 0.077s
# 142. villa vazquez: Results not Found :( 0.103s
# 143. makat: Results Found! 0.297s
# 144. chapais: Results Found! 0.091s
# 145. ancud: Results Found! 0.076s
# 146. narsaq: Results Found! 0.073s
# 147. richards bay: Results Found! 0.143s
# 148. nanyang: Results Found! 0.089s
# 149. itamarandiba: Results Found! 0.075s
# 150. nikolskoye: Results Found! 0.074s
# 151. ola: Results Found! 0.072s
# 152. livingston: Results Found! 0.302s
# 153. qaanaaq: Results Found! 0.073s
# 154. punta arenas: Results Found! 0.098s
# 155. ekhabi: Results Found! 0.148s
# 156. lata: Results Found! 0.069s
# 157. scarborough: Results Found! 0.071s
# 158. asau: Results Found! 0.069s
# 159. palabuhanratu: Results not Found :( 0.088s
# 160. lubango: Results Found! 0.072s
# 161. deh rawud: Results not Found :( 0.321s
# 162. quattro castella: Results Found! 0.075s
# 163. codrington: Results Found! 0.067s
# 164. bonham: Results Found! 0.167s
# 165. anchorage: Results Found! 0.104s
# 166. kingaroy: Results Found! 0.072s
# 167. tres picos: Results Found! 0.067s
# 168. san lazaro: Results Found! 0.069s
# 169. ambodifototra: Results not Found :( 0.287s
# 170. saint-pierre: Results Found! 0.070s
# 171. hami: Results Found! 0.082s
# 172. mananjary: Results Found! 0.170s
# 173. tagusao: Results Found! 0.068s
# 174. nyurba: Results Found! 0.070s
# 175. caidian: Results Found! 0.104s
# 176. turukhansk: Results Found! 0.103s
# 177. tuatapere: Results Found! 0.334s
# 178. williston: Results Found! 0.090s
# 179. herat: Results Found! 0.094s
# Executed 60 calls, waiting for 50.69 seconds
# 180. bargal: Results not Found :( 0.106s
# 181. lolua: Results not Found :( 0.272s
# 182. iqaluit: Results Found! 0.088s
# 183. chokurdakh: Results Found! 0.069s
# 184. mar del plata: Results Found! 0.272s
# 185. corn island: Results Found! 0.303s
# 186. inuvik: Results Found! 0.491s
# 187. mareeba: Results Found! 0.272s
# 188. kokopo: Results Found! 0.276s
# 189. ahipara: Results Found! 0.295s
# 190. el balyana: Results not Found :( 0.078s
# 191. kavaratti: Results Found! 0.077s
# 192. meulaboh: Results Found! 0.136s
# 193. lincoln: Results Found! 0.084s
# 194. khonuu: Results not Found :( 0.072s
# 195. salalah: Results Found! 0.070s
# 196. souillac: Results Found! 0.391s
# 197. la plaine: Results Found! 0.269s
# 198. beira: Results Found! 0.363s
# 199. macapa: Results Found! 0.097s
# 200. abu samrah: Results Found! 0.277s
# 201. victoria: Results Found! 0.088s
# 202. raduzhnyy: Results Found! 0.287s
# 203. norman wells: Results Found! 0.304s
# 204. la roda: Results Found! 0.333s
# 205. bellevue: Results Found! 0.283s
# 206. dongdu: Results Found! 0.362s
# 207. nsanje: Results Found! 0.372s
# 208. tukrah: Results Found! 0.384s
# 209. araouane: Results Found! 0.270s
# 210. kamina: Results Found! 0.362s
# 211. stornoway: Results Found! 0.271s
# 212. rancho palos verdes: Results Found! 0.337s
# 213. leningradskiy: Results Found! 0.097s
# 214. airai: Results Found! 0.069s
# 215. ambilobe: Results Found! 0.496s
# 216. saldanha: Results Found! 0.151s
# 217. tshikapa: Results Found! 0.272s
# 218. cravo norte: Results Found! 0.320s
# 219. bavly: Results Found! 0.281s
# 220. chadiza: Results Found! 0.363s
# 221. sevenoaks: Results Found! 0.107s
# 222. oban: Results Found! 0.529s
# 223. roma: Results Found! 0.144s
# 224. sisimiut: Results Found! 0.279s
# 225. shihezi: Results Found! 0.320s
# 226. lebu: Results Found! 0.090s
# 227. merauke: Results Found! 0.284s
# 228. avera: Results Found! 0.073s
# 229. paamiut: Results Found! 0.274s
# 230. goderich: Results Found! 0.278s
# 231. aykhal: Results Found! 0.269s
# 232. praia da vitoria: Results Found! 0.334s
# 233. eureka: Results Found! 0.075s
# 234. vestmannaeyjar: Results Found! 0.071s
# 235. santiago del estero: Results Found! 0.477s
# 236. mayumba: Results Found! 0.151s
# 237. coihaique: Results Found! 0.071s
# 238. san roque: Results Found! 0.270s
# 239. yarada: Results Found! 0.316s
# Executed 60 calls, waiting for 44.88 seconds
# 240. amderma: Results not Found :( 0.232s
# 241. thinadhoo: Results Found! 0.312s
# 242. silca: Results Found! 0.277s
# 243. chor: Results Found! 0.081s
# 244. houston: Results Found! 0.266s
# 245. maldonado: Results Found! 0.382s
# 246. artyk: Results not Found :( 0.085s
# 247. bay roberts: Results Found! 0.274s
# 248. carnarvon: Results Found! 0.270s
# 249. nador: Results Found! 0.071s
# 250. qaqortoq: Results Found! 0.303s
# 251. mackay: Results Found! 0.313s
# 252. guiratinga: Results Found! 0.324s
# 253. aflu: Results not Found :( 0.091s
# 254. pochutla: Results Found! 0.077s
# 255. bandarbeyla: Results Found! 0.069s
# 256. bow island: Results Found! 0.354s
# 257. dingle: Results Found! 0.070s
# 258. kahului: Results Found! 0.070s
# 259. tokoroa: Results Found! 0.480s
# 260. senanga: Results Found! 0.321s
# 261. ouadda: Results Found! 0.470s
# 262. yefira: Results not Found :( 0.100s
# 263. korla: Results Found! 0.072s
# 264. mountain home: Results Found! 0.341s
# 265. high level: Results Found! 0.275s
# 266. castro: Results Found! 0.275s
# 267. vaitupu: Results not Found :( 0.076s
# 268. sacile: Results Found! 0.311s
# 269. santo tomas: Results Found! 0.268s
# 270. bolshaya murta: Results not Found :( 0.280s
# 271. bathsheba: Results Found! 0.089s
# 272. broken hill: Results Found! 0.285s
# 273. robertsport: Results Found! 0.298s
# 274. port augusta: Results Found! 0.070s
# 275. ngukurr: Results not Found :( 0.299s
# 276. san patricio: Results Found! 0.339s
# 277. abrau-dyurso: Results Found! 0.271s
# 278. sorong: Results Found! 0.081s
# 279. puerto narino: Results Found! 0.305s
# 280. saint-joseph: Results Found! 0.075s
# 281. kaeo: Results Found! 0.070s
# 282. nadym: Results Found! 0.076s
# 283. namatanai: Results Found! 0.188s
# 284. vardo: Results Found! 0.072s
# 285. nagorsk: Results Found! 0.471s
# 286. fitii: Results Found! 0.271s
# 287. luwuk: Results Found! 0.357s
# 288. marcona: Results not Found :( 0.131s
# 289. massakory: Results Found! 0.508s
# 290. northam: Results Found! 0.355s
# 291. lavrentiya: Results Found! 0.076s
# 292. cardston: Results Found! 0.322s
# 293. castro alves: Results Found! 0.385s
# 294. nchelenge: Results Found! 0.274s
# 295. thunder bay: Results Found! 0.072s
# 296. olafsvik: Results Found! 0.352s
# 297. umm kaddadah: Results Found! 0.308s
# 298. mwinilunga: Results Found! 0.277s
# 299. hihifo: Results not Found :( 0.073s
# Executed 60 calls, waiting for 45.43 seconds
# 300. ilulissat: Results Found! 0.075s
# 301. cabedelo: Results Found! 0.278s
# 302. constitucion: Results Found! 0.071s
# 303. moose factory: Results Found! 0.298s
# 304. bubaque: Results Found! 0.476s
# 305. leh: Results Found! 0.151s
# 306. kaitangata: Results Found! 0.072s
# 307. tabou: Results Found! 0.287s
# 308. ajaccio: Results Found! 0.497s
# 309. ullapool: Results Found! 0.346s
# 310. mecca: Results Found! 0.070s
# 311. zharkent: Results Found! 0.329s
# 312. maumere: Results Found! 0.383s
# 313. saint-georges: Results Found! 0.071s
# 314. yerbogachen: Results Found! 0.274s
# 315. nemuro: Results Found! 0.276s
# 316. ilo: Results Found! 0.377s
# 317. charleville-mezieres: Results Found! 0.285s
# 318. belmonte: Results Found! 0.074s
# 319. san juan del sur: Results Found! 0.510s
# 320. shizunai: Results Found! 0.355s
# 321. anloga: Results Found! 0.097s
# 322. shingu: Results Found! 0.072s
# 323. whitehorse: Results Found! 0.315s
# 324. ardakan: Results Found! 0.288s
# 325. el alto: Results Found! 0.299s
# 326. lac du bonnet: Results Found! 0.333s
# 327. mehamn: Results Found! 0.078s
# 328. lompoc: Results Found! 0.081s
# 329. kawana waters: Results not Found :( 0.096s
# 330. pangnirtung: Results Found! 0.161s
# 331. west fargo: Results Found! 0.271s
# 332. coquimbo: Results Found! 0.292s
# 333. kloulklubed: Results Found! 0.092s
# 334. sambava: Results Found! 0.276s
# 335. aksu: Results Found! 0.085s
# 336. otjiwarongo: Results Found! 0.273s
# 337. prince rupert: Results Found! 0.293s
# 338. vila velha: Results Found! 0.072s
# 339. labutta: Results not Found :( 0.076s
# 340. luanda: Results Found! 0.298s
# 341. ketchikan: Results Found! 0.073s
# 342. bratslav: Results Found! 0.445s
# 343. medicine hat: Results Found! 0.086s
# 344. rawson: Results Found! 0.069s
# 345. batagay-alyta: Results Found! 0.072s
# 346. concordia: Results Found! 0.375s
# 347. tiksi: Results Found! 0.071s
# 348. satitoa: Results not Found :( 0.074s
# 349. cap malheureux: Results Found! 0.511s
# 350. dinguiraye: Results Found! 0.371s
# 351. knysna: Results Found! 0.368s
# 352. isangel: Results Found! 0.087s
# 353. anadyr: Results Found! 0.284s
# 354. port keats: Results Found! 0.274s
# 355. odessa: Results Found! 0.358s
# 356. casimiro castillo: Results Found! 0.385s
# 357. pontian kecil: Results Found! 0.294s
# 358. iisalmi: Results Found! 0.342s
# 359. coihueco: Results Found! 0.275s
# Executed 60 calls, waiting for 45.09 seconds
# 360. laguna: Results Found! 0.404s
# 361. labuhan: Results Found! 0.323s
# 362. tarakan: Results Found! 0.281s
# 363. barcelos: Results Found! 0.358s
# 364. otradnoye: Results Found! 0.103s
# 365. burpengary: Results Found! 0.267s
# 366. rio gallegos: Results Found! 0.088s
# 367. tyler: Results Found! 0.075s
# 368. jatiroto: Results Found! 0.273s
# 369. puerto carreno: Results Found! 0.276s
# 370. caconda: Results Found! 0.284s
# 371. yar-sale: Results Found! 0.084s
# 372. komsomolskiy: Results Found! 0.071s
# 373. broome: Results Found! 0.076s
# 374. ucluelet: Results Found! 0.155s
# 375. mrakovo: Results Found! 0.337s
# 376. khorramshahr: Results Found! 0.564s
# 377. encruzilhada do sul: Results Found! 0.738s
# 378. ust-nera: Results Found! 0.245s
# 379. riverton: Results Found! 0.917s
# 380. zyryanka: Results Found! 0.558s
# 381. vostok: Results Found! 0.467s
# 382. mallapuram: Results Found! 0.386s
# 383. halalo: Results not Found :( 0.245s
# 384. szob: Results Found! 0.782s
# 385. port lincoln: Results Found! 0.244s
# 386. rolla: Results Found! 0.785s
# 387. general pico: Results Found! 0.515s
# 388. karaul: Results not Found :( 0.589s
# 389. gaeta: Results Found! 0.438s
# 390. eydhafushi: Results Found! 0.277s
# 391. pinheiro machado: Results Found! 0.398s
# 392. narayangarh: Results Found! 0.344s
# 393. vila praia de ancora: Results Found! 0.269s
# 394. krasnovishersk: Results Found! 0.338s
# 395. reinosa: Results Found! 0.410s
# 396. kutum: Results Found! 0.072s
# 397. westport: Results Found! 0.073s
# 398. gondar: Results Found! 0.287s
# 399. saleaula: Results not Found :( 0.073s
# 400. serra talhada: Results Found! 0.491s
# 401. saquena: Results Found! 0.384s
# 402. padang: Results Found! 0.098s
# 403. taywarah: Results Found! 0.273s
# 404. panaba: Results Found! 0.500s
# 405. salinopolis: Results Found! 0.141s
# 406. hervey bay: Results Found! 0.295s
# 407. conceicao do mato dentro: Results Found! 0.341s
# 408. shwebo: Results Found! 0.282s
# 409. parakai: Results Found! 0.365s
# 410. dikson: Results Found! 0.074s
# 411. sola: Results Found! 0.284s
# 412. inta: Results Found! 0.298s
# 413. tongling: Results Found! 0.396s
# 414. kitui: Results Found! 0.325s
# 415. pervomayskiy: Results Found! 0.279s
# 416. maloy: Results Found! 0.377s
# 417. skibbereen: Results Found! 0.363s
# 418. poum: Results Found! 0.105s
# 419. kailua: Results Found! 0.282s
# Executed 60 calls, waiting for 39.96 seconds
# 420. gat: Results Found! 0.078s
# 421. masunga: Results Found! 0.412s
# 422. vao: Results Found! 0.079s
# 423. taquaritinga do norte: Results Found! 0.316s
# 424. zabaykalsk: Results Found! 0.277s
# 425. makakilo city: Results Found! 0.081s
# 426. eirunepe: Results Found! 0.506s
# 427. beeville: Results Found! 0.344s
# 428. kangasala: Results Found! 0.407s
# 429. abu kamal: Results Found! 0.383s
# 430. urumqi: Results Found! 0.294s
# 431. port antonio: Results Found! 0.342s
# 432. flin flon: Results Found! 0.273s
# 433. port-gentil: Results Found! 0.187s
# 434. camacha: Results Found! 0.097s
# 435. roebourne: Results Found! 0.448s
# 436. moindou: Results Found! 0.294s
# 437. cayeli: Results Found! 0.213s
# 438. gardan diwal: Results not Found :( 0.079s
# 439. buqayq: Results not Found :( 0.073s
# 440. kulhudhuffushi: Results Found! 0.344s
# 441. eldorado: Results Found! 0.278s
# 442. estreito: Results Found! 0.355s
# 443. aleysk: Results Found! 0.378s
# 444. fortuna: Results Found! 0.092s
# 445. sistranda: Results Found! 0.078s
# 446. sumenep: Results Found! 0.288s
# 447. auki: Results Found! 0.075s
# 448. hambantota: Results Found! 0.073s
# 449. rawannawi: Results not Found :( 0.072s
# 450. yamada: Results Found! 0.293s
# 451. muroto: Results Found! 0.274s
# 452. saint anthony: Results Found! 0.168s
# 453. banjar: Results Found! 0.275s
# 454. shahpura: Results Found! 0.292s
# 455. karratha: Results Found! 0.095s
# 456. falmouth: Results Found! 0.107s
# 457. guantanamo: Results Found! 0.267s
# 458. haines junction: Results Found! 0.689s
# 459. lee: Results Found! 0.296s
# 460. jambi: Results Found! 0.311s
# 461. marsh harbour: Results Found! 0.503s
# 462. sorvag: Results not Found :( 0.182s
# 463. hudson bay: Results Found! 0.274s
# 464. alta floresta: Results Found! 0.076s
# 465. salvador: Results Found! 0.493s
# 466. soyo: Results Found! 0.355s
# 467. erzin: Results Found! 0.068s
# 468. tukuyu: Results Found! 0.328s
# 469. guerrero negro: Results Found! 0.072s
# 470. bonavista: Results Found! 0.301s
# 471. laibin: Results Found! 0.293s
# 472. gwadar: Results Found! 0.343s
# 473. kokkola: Results Found! 0.270s
# 474. abu zabad: Results Found! 0.151s
# 475. pietra ligure: Results Found! 0.276s
# 476. kotelnikovo: Results Found! 0.311s
# 477. kuytun: Results Found! 0.076s
# 478. batsfjord: Results Found! 0.297s
# 479. jacareacanga: Results Found! 0.309s
# Executed 60 calls, waiting for 44.09 seconds
# 480. ostersund: Results Found! 0.340s
# 481. tidore: Results not Found :( 0.077s
# 482. andenes: Results Found! 0.275s
# 483. changli: Results Found! 0.292s
# 484. honolulu: Results Found! 0.274s
# 485. cam ranh: Results Found! 0.279s
# 486. gravdal: Results Found! 0.357s
# 487. utete: Results Found! 0.382s
# 488. bershet: Results Found! 0.416s
# 489. inderborskiy: Results not Found :( 0.080s
# 490. lianran: Results Found! 0.273s
# 491. tabas: Results Found! 0.268s
# 492. lipari: Results Found! 0.348s
# 493. tsihombe: Results not Found :( 0.072s
# 494. sabang: Results Found! 0.071s
# 495. chulakivka: Results Found! 0.480s
# 496. filingue: Results Found! 0.374s
# 497. tonstad: Results Found! 0.276s
# 498. palana: Results Found! 0.357s
# 499. cabo san lucas: Results Found! 0.115s
# 500. mollendo: Results Found! 0.282s
# 501. evensk: Results Found! 0.068s
# 502. simplicio mendes: Results Found! 0.288s
# 503. quelimane: Results Found! 0.469s
# 504. hasaki: Results Found! 0.173s
# 505. ust-koksa: Results Found! 0.334s
# 506. abalak: Results Found! 0.497s
# 507. lamu: Results Found! 0.147s
# 508. lasa: Results Found! 0.092s
# 509. luderitz: Results Found! 0.281s
# 510. san cristobal: Results Found! 0.505s
# 511. stepnyak: Results Found! 0.362s
# 512. minab: Results Found! 0.090s
# 513. at-bashi: Results Found! 0.302s
# 514. shenjiamen: Results Found! 0.267s
# 515. kerrville: Results Found! 0.148s
# 516. fairmont: Results Found! 0.273s
# 517. tonj: Results Found! 0.071s
# 518. baisha: Results Found! 0.531s
# 519. quime: Results Found! 0.161s
# 520. barra do garcas: Results Found! 0.270s
# 521. moron: Results Found! 0.284s
# 522. pacific grove: Results Found! 0.100s
# 523. mafra: Results Found! 0.287s
# 524. morondava: Results Found! 0.090s
# 525. hofn: Results Found! 0.070s
# 526. koygorodok: Results Found! 0.438s
# 527. mergui: Results not Found :( 0.104s
# 528. polyarnyy: Results Found! 0.274s
# 529. bundaberg: Results Found! 0.075s
# 530. pringsewu: Results Found! 0.640s
# 531. haradok: Results Found! 0.291s
# 532. college: Results Found! 0.074s
# 533. conceicao do araguaia: Results Found! 0.301s
# 534. bokspits: Results not Found :( 0.294s
# 535. ishigaki: Results Found! 0.102s
# 536. udimskiy: Results Found! 0.282s
# 537. plouzane: Results Found! 0.308s
# 538. sarkand: Results Found! 0.513s
# 539. cetraro: Results Found! 0.272s
# Executed 60 calls, waiting for 43.45 seconds
# 540. kenai: Results Found! 0.332s
# 541. qianan: Results Found! 0.160s
# 542. coulihaut: Results not Found :( 0.075s
# 543. adrar: Results Found! 0.072s
# 544. champerico: Results Found! 0.072s
# 545. madison: Results Found! 0.071s
# 546. charters towers: Results Found! 0.318s
# 547. belaya gora: Results Found! 0.310s
# 548. timaru: Results Found! 0.286s
# 549. uspenka: Results Found! 0.348s
# 550. roald: Results Found! 0.079s
# 551. chimore: Results Found! 0.101s
# 552. zakupne: Results Found! 0.303s
# 553. ondorhaan: Results not Found :( 0.075s
# 554. mount gambier: Results Found! 0.081s
# 555. itarema: Results Found! 0.070s
# 556. rocha: Results Found! 0.271s
# 557. noumea: Results Found! 0.078s
# 558. elbrus: Results Found! 0.288s
# 559. asha: Results Found! 0.303s
# 560. neiafu: Results Found! 0.077s
# 561. kampot: Results Found! 0.478s
# 562. maceio: Results Found! 0.146s
# 563. bucerias: Results Found! 0.291s
# 564. fiumicino: Results Found! 0.077s
# 565. weligama: Results Found! 0.784s
# 566. logrono: Results Found! 0.285s
# 567. karpathos: Results Found! 0.484s
# 568. morant bay: Results Found! 0.153s
# 569. san andres: Results Found! 0.071s
# 570. udachnyy: Results Found! 0.071s
# 571. diamantino: Results Found! 0.097s
# 572. vestmanna: Results Found! 0.071s
# 573. seoul: Results Found! 0.291s
# 574. kandrian: Results Found! 0.346s
# 575. santona: Results Found! 0.303s
# 576. ambon: Results Found! 0.332s
# 577. halmstad: Results Found! 0.280s
# 578. easley: Results Found! 0.381s
# 579. abnub: Results Found! 0.071s
# 580. kalmunai: Results Found! 0.275s
# 581. muros: Results Found! 0.383s
# 582. havoysund: Results Found! 0.271s
# 583. great yarmouth: Results Found! 0.072s
# 584. morada nova: Results Found! 0.291s
# 585. kolpashevo: Results Found! 0.074s
# 586. bayevo: Results Found! 0.287s
# 587. kabanjahe: Results Found! 0.296s
# 588. monrovia: Results Found! 0.088s
# 589. port hedland: Results Found! 0.482s
# 590. puerto baquerizo moreno: Results Found! 0.297s
# 591. leszno: Results Found! 0.488s
# 592. talcahuano: Results Found! 0.070s
# 593. marrakesh: Results Found! 0.088s
# 594. bud: Results Found! 0.104s
# 595. bezopasnoye: Results Found! 0.360s
# 596. margate: Results Found! 0.072s
# 597. palaikastron: Results Found! 0.295s
# 598. amberley: Results Found! 0.087s
# 599. dekar: Results Found! 0.284s
# Executed 60 calls, waiting for 45.92 seconds
# 600. esso: Results Found! 0.297s
# 601. condado: Results Found! 0.268s
# 602. nelson bay: Results Found! 0.510s
# 603. brigantine: Results Found! 0.274s
# 604. hokitika: Results Found! 0.281s
# 605. nioro: Results Found! 0.490s
# Total Execution: 602.1850590705872s

# %% [markdown]
# ## Inspect the Data

# %%
weather_df
# Out:
#                City Response Code  Exec Time(s)  Longitude  Latitude Weather  \
# 0       tuktoyaktuk           200      0.379629  -133.0374   69.4541    Mist
# 1           aklavik           200      0.400749  -135.0107   68.2191    Snow
# 2         caravelas           200      0.272465   -39.2481  -17.7125  Clouds
# 3             kapaa           200      0.277769  -159.3190   22.0752  Clouds
# 4    severo-kurilsk           200      0.478854   156.1250   50.6789    Snow
# ..              ...           ...           ...        ...       ...     ...
# 600         condado           200      0.348705   -79.8403   21.8767  Clouds
# 601      nelson bay           200      0.379025   152.1500  -32.7167  Clouds
# 602      brigantine           200      0.378560   -74.3646   39.4101   Clear
# 603        hokitika           200      0.270262   170.9667  -42.7167  Clouds
# 604           nioro           200      0.364657   -15.7500   13.3500   Clear
#
#     Temperature (F) Cloudiness (%)  Wind Speed (mph) Humidity (%)
# 0                14             90              5.75           92
# 1              26.6             90              9.22           74
# 2             74.16             79              9.26           70
# 3             79.14             40             12.66           69
# 4             35.67            100             23.20           97
# ..              ...            ...               ...          ...
# 600           86.58            100              9.22           70
# 601           55.27             68              5.77          100
# 602           66.97              1             12.66           19
# 603           53.37             33              2.82           73
# 604           85.21              4             15.70           30
#
# [605 rows x 10 columns]

# %%
weather_df.describe()
# Out:
#        Exec Time(s)   Longitude    Latitude  Wind Speed (mph)
# count    605.000000  559.000000  559.000000        559.000000
# mean       0.335224   14.736987   20.114588          7.781503
# std        0.154304   90.344737   33.709138          5.615736
# min        0.070046 -175.200000  -54.800000          0.110000
# 25%        0.277170  -64.009150   -8.753100          3.635000
# 50%        0.334946   16.433300   24.093400          5.970000
# 75%        0.386454   87.791900   48.736250         10.360000
# max        1.814944  179.316700   78.218600         37.980000

# %% [markdown]
# ## Visualize Relationships

# %% [markdown]
# ###  Temperature (F) vs. Latitude

# %%
weather_df.plot(x="Latitude",y="Temperature (F)", kind="scatter", title="Temperature (F) vs. Latitude   (5/1/21)")
plt.savefig("Output/Global_Temperature_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Observations
# - Predictably, temperature is higher at the equator (Lat=0) than it is near the poles.
# - The data is skewed toward the +Lats because it is spring in the Northern Hemisphere

# %% [markdown]
# ### Humidity (%) vs. Latitude

# %%
weather_df.plot(x="Latitude",y="Humidity (%)", kind="scatter", title = "Humidity (%) vs. Latitude   (5/1/21)")
plt.savefig("Output/Global_Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Observations
# - It seems like humidity globally tends to be above 40-50%, with the majority of exceptions occurring in the Northern Hemisphere
# - However, because this code has been executed during spring, we might expect different distributions during other months

# %% [markdown]
# ### Cloudiness (%) vs. Latitude

# %%
weather_df.plot(x="Latitude",y="Cloudiness (%)", kind="scatter", title = "Cloudiness (%) vs. Latitude   (5/1/21)")
plt.savefig("Output/Global_Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Observations
# - Latitude seems to have no effect on Cloud Coverage, but
# - Cloudiness is clustered around multiples of 20. Presumably this is due to data recording practices

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude

# %%
weather_df.plot(x="Latitude",y="Wind Speed (mph)", kind="scatter", title = "Wind Speed (mph) vs. Latitude   (5/1/21)")
plt.savefig("Output/Global_WindSpeed_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Observations
# - There does not seem to be a strong correlation between wind speed and latitude

# %% [markdown]
# ## Regression Analysis

# %%
# Create Dataframe for Northern Hemisphere
north = weather_df[weather_df["Latitude"]>=0]
north
# Out:
#                City Response Code  Exec Time(s)  Longitude  Latitude Weather  \
# 0       tuktoyaktuk           200      0.379629  -133.0374   69.4541    Mist
# 1           aklavik           200      0.400749  -135.0107   68.2191    Snow
# 3             kapaa           200      0.277769  -159.3190   22.0752  Clouds
# 4    severo-kurilsk           200      0.478854   156.1250   50.6789    Snow
# 5             aswan           200      0.352355    32.9070   24.0934   Clear
# ..              ...           ...           ...        ...       ...     ...
# 597        amberley           200      0.294196   -84.4280   39.2048   Clear
# 599            esso           200      0.273335   158.7000   55.9333  Clouds
# 600         condado           200      0.348705   -79.8403   21.8767  Clouds
# 602      brigantine           200      0.378560   -74.3646   39.4101   Clear
# 604           nioro           200      0.364657   -15.7500   13.3500   Clear
#
#     Temperature (F) Cloudiness (%)  Wind Speed (mph) Humidity (%)
# 0                14             90              5.75           92
# 1              26.6             90              9.22           74
# 3             79.14             40             12.66           69
# 4             35.67            100             23.20           97
# 5             86.38              0              9.82           14
# ..              ...            ...               ...          ...
# 597           71.04              1             16.11           33
# 599            35.1            100              5.57           99
# 600           86.58            100              9.22           70
# 602           66.97              1             12.66           19
# 604           85.21              4             15.70           30
#
# [374 rows x 10 columns]

# %%
# Create Dataframe for Southern Hemisphere
south = weather_df[weather_df["Latitude"]<0]
south
# Out:
#                         City Response Code  Exec Time(s)  Longitude  Latitude  \
# 2                  caravelas           200      0.272465   -39.2481  -17.7125
# 7                   bengkulu           200      0.110521   102.2655   -3.8004
# 14                    hobart           200      0.299119   147.3294  -42.8794
# 16                   ushuaia           200      0.386284   -68.3000  -54.8000
# 17                 busselton           200      0.295580   115.3333  -33.6500
# ..                       ...           ...           ...        ...       ...
# 589  puerto baquerizo moreno           200      0.548265   -89.6000   -0.9000
# 591               talcahuano           200      0.328368   -73.1167  -36.7167
# 598                    dekar           200      0.331317    21.9333  -21.5333
# 601               nelson bay           200      0.379025   152.1500  -32.7167
# 603                 hokitika           200      0.270262   170.9667  -42.7167
#
#     Weather Temperature (F) Cloudiness (%)  Wind Speed (mph) Humidity (%)
# 2    Clouds           74.16             79              9.26           70
# 7    Clouds           75.15             73              3.96           88
# 14    Clear           51.53              0              8.05           76
# 16   Clouds              41             20              4.61           70
# 17    Clear           53.17              6              3.11           96
# ..      ...             ...            ...               ...          ...
# 589  Clouds            84.2             20             14.97           70
# 591  Clouds            57.2             90              6.91           94
# 598   Clear           60.37              0              7.78           27
# 601  Clouds           55.27             68              5.77          100
# 603  Clouds           53.37             33              2.82           73
#
# [185 rows x 10 columns]

# %% [markdown]
# ###  Temperature (F) vs. Latitude

# %%
xlabel = "Latitude"
ylabel = "Temperature (F)"


#North
hemi = "Northern Hemisphere"
X=north[xlabel].astype(float)
Y=north[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=55, y=60 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()


#South
hemi = "Southern Hemisphere"
X=south[xlabel].astype(float)
Y=south[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=-55, y=60 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()

# %% [markdown]
# #### Observations
# - The two lines are nice approximate inverses of each other
# - My guess is that at a solstice the slopes are actually perpendicular

# %% [markdown]
# ###  Humidity (%) vs. Latitude

# %%
xlabel = "Latitude"
ylabel = "Humidity (%)"


#North
hemi = "Northern Hemisphere"
X=north[xlabel].astype(float)
Y=north[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=55, y=10 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()


#South
hemi = "Southern Hemisphere"
X=south[xlabel].astype(float)
Y=south[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=-55, y=10 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()

# %% [markdown]
# #### Observations
# - The two lines have small, positive, and approximately equal slope. This tells me that there is a small humidity preference for the northern hemisphere.
# - And yet, the spread in the northern hemisphere is higher. I suspect that would be meaningful to a meteorologist, but I cannot speculate on the mechanism behind any culprit

# %% [markdown]
# ###  Cloudiness (%) vs. Latitude

# %%
xlabel = "Latitude"
ylabel = "Cloudiness (%)"


#North
hemi = "Northern Hemisphere"
X=north[xlabel].astype(float)
Y=north[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=55, y=50 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()


#South
hemi = "Southern Hemisphere"
X=south[xlabel].astype(float)
Y=south[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=-55, y=45 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()

# %% [markdown]
# #### Observations
# - I really don't think the data matches the regression line at all. These charts are meaningless.

# %% [markdown]
# ###  Wind Speed (mph) vs. Latitude

# %%
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"


#North
hemi = "Northern Hemisphere"
X=north[xlabel].astype(float)
Y=north[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=55, y=25 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()


#South
hemi = "Southern Hemisphere"
X=south[xlabel].astype(float)
Y=south[ylabel].astype(float)

plt.scatter(x=X,y=Y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(f"{ylabel} vs. {xlabel} in {hemi} on 5/1/21")

m, b = np.polyfit(X, Y, 1)
plt.plot(X, m*X + b, "r--")
plt.text(x=-55, y=25 , s=f"Y = {m:.2f}*X + {b:.2f}", fontdict= {'color':'red'})

plt.savefig(f"Output/{hemi}_{ylabel}_vs_{xlabel}.png")
plt.show()

# %% [markdown]
# #### Observations
# - Once again, there is no correlation. But this time the slope is effectively 0, so even stronger evidence.
